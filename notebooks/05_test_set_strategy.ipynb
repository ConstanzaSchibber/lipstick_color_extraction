# %% [markdown]
# # Test Set Strategy
#
# **Status: placeholder, not yet implemented.**
#
# Split out from `04_a_validation_set_strategy.ipynb`, which originally covered
# both validation and test. This notebook will build the independent **test**
# set for the models trained in notebook 06 — evaluated once, at the end, on
# products the validation set never touched.
#
# TODO: decide and implement the test-set sampling strategy (candidate: a temporal
# split on `date_added`, as notebook 04_a previously used before that logic was
# removed pending redesign).
